# %% [markdown]
# # Actividad 3
#
# En los [lineamientos](https://docs.google.com/document/d/1Zx0ow7Lk-d5lUDW_egM0LdQoFS4-SxLRRkq0mJZgGRw/edit?usp=sharing) dados para resolver esta actividad también se encuentra un enlace a la [grilla](https://docs.google.com/spreadsheets/d/1VNbFLX1ugiLGg4IGuLzlZw_QGnj3nyOCcDHcH42K-LM/edit?gid=937426456#gid=937426456) con la que será calificada.
#
# Para realizar el ejercicio deben descargar el archivo denominado [logs_catedra.csv]() y ubicarlo en una carpeta denomina **"archivos"**. Es decir que tendrán una estructura similar a:
#
# <center>
# <img src="estructura_de_archivos.png" alt="Estructura de archivos de la actividad" style="width:350px;"/>
# </center>
#
#
# Este archivo  contiene el registro de accesos al entorno catedras.linti correspondiente al curso.

# %% [markdown]
# ## Enunciado a evaluar

# %% [markdown]
# **EJERCICIO 1.** Escribir una función que retorne los usuarios que realizaron la actividad 1 de Python plus correpondiente al turno de la mañana desde una IP de la facultad. Esta función recibe un parámetro opcional que indica si los nombres de usuario se muestran en mayúsculas **("M")**, minúsculas **("m")** o como aparecen en el dataset **(None)**. Por defecto la función muestra tal como aparecen en el dataset.
#
# **NOTA:** la información sobre la actividad 1 de Python plus  se obtiene  verificando que la columna  "Nombre evento" contenga el texto "Intento de cuestionario actualizado"  y la columna "Contexto del evento" contenga el texto "Cuestionario: ACT 1  - INFO - Turno MAÑANA".
#
# Las direcciones IP de la facultad comienza con "163.10"
#
# **EJERCICIO 2.** Utilizando la función anterior, escribir un programa que ingrese desde el teclado un menú de opciones que permita mostrar los usuarios que realizaron la actividad 1 de Python plus desde una IP de la facultad con los nombres en mayúsculas, minúsculas o tal como aparecen en el dataset.

# %% [markdown]
# ### Solución a analizar
#
# **EJERCICIO 1**

# %%
import csv
from pathlib import Path
import string
file_route = Path('Archivos') / "logs_catedra.csv"
entregaron = []
desde_la_facu = False
nombre=2
contexto=4
evento=6
def make_list(i,tipo):
    if(i[contexto]=="Cuestionario: ACT 1  - INFO - Turno MAÑANA" and i[evento]=="Intento de cuestionario actualizado"):
                        if(tipo==None):
                            entregaron.append(i[nombre])
                        elif(tipo=="m"):
                            entregaron.append(i[nombre].lower())
                        else:
                            entregaron.append(i[nombre].upper())  


def realizaron(desde_la_facu,tipo=None):
    
    with open(file_route, encoding='utf-8')as archivo:
        lector = list(csv.reader(archivo,delimiter=','))
        
        for i in lector:
            if(desde_la_facu):
                if(i[7].startswith("163.10")):
                    make_list(i,tipo)
            else:
               make_list(i,tipo)

# %% [markdown]
# **EJERCICIO 2**

# %%
Menu={1:"mayusculas",
      2:"minusculas",
      3:"defecto"}
# armado de manu

aux = input("Hola! como quieres que se muestren los datos?" \
" 1 para Mayusculas" \
" 2 para Minusculas" \
" 3 para Default    ")
str(aux)
realizaron(True,aux)
print(entregaron)
# Out:
# ['KANGASKHANMEGA KANGASKHAN', 'KANGASKHANMEGA KANGASKHAN', 'GASTLY', 'GASTLY', 'KANGASKHANMEGA KANGASKHAN', 'GASTLY', 'RHYDON', 'GASTLY', 'PIDGEOTTO', 'KANGASKHANMEGA KANGASKHAN', 'CHARIZARDMEGA CHARIZARD X', 'CHARIZARDMEGA CHARIZARD Y', 'RHYDON', 'MR. MIME', 'EKANS', 'MR. MIME', 'CLEFAIRY', 'RHYDON', 'PIDGEOTTO', 'MR. MIME', 'EXEGGCUTE', 'KADABRA', 'KADABRA', 'CHARIZARDMEGA CHARIZARD X', 'PINSIR', 'KRABBY', 'RHYDON', 'KOFFING', 'KADABRA', 'KRABBY', 'PINSIR', 'KRABBY', 'KRABBY', 'PINSIR', 'VICTREEBEL', 'KAKUNA', 'CHARMELEON', 'CHARIZARDMEGA CHARIZARD Y', 'KADABRA', 'HITMONCHAN', 'GOLDEEN', 'RATICATE', 'CHARMELEON', 'MAGIKARP', 'GRAVELER', 'KADABRA', 'CHANSEY', 'PINSIR', 'EXEGGCUTE', 'KRABBY', 'KOFFING', 'EKANS', 'KRABBY', 'SCYTHER', 'GOLDEEN', 'KRABBY', 'CHARMELEON', 'KRABBY', 'KRABBY', 'KOFFING', 'SEAKING', 'LAPRAS', 'CLEFAIRY', 'EKANS', 'CUBONE', 'CHARIZARDMEGA CHARIZARD X', 'TANGELA', 'MR. MIME', 'PINSIR', 'PINSIR', 'GRAVELER', 'KRABBY', 'PINSIR', 'GOLDEEN', 'PINSIRMEGA PINSIR', '
# ...

# %% [markdown]
# ## Parte I - Análisis de la solución
#
# Respondé las siguientes preguntas:

# %% [markdown]
# 1.1 **¿Qué estructuras de datos se utilizan para guardar los resultados a mostrar? ¿Te parece la más adecuada? Si no es así, ¿cuál usarías?**

# %% [markdown]
# **RTA.**
#
# La estructura que se utilizo para guardar los resultados fue una lista, me parece una estructura adecuada pero si se considera que el nombre completo del alumno es unico, un set seria la mejor estructura para este caso.

# %% [markdown]
# 1.2. **Explicá detalladamente qué hace las funciones del ejercicio 1 e indicá si te parece adecuado el uso de los condicionales JUSTIFCANDO la respuesta.**

# %% [markdown]
# **RTA.**
#
# La funcion de make a list, lo primero que hace definir la estructura vacia, en este  caso una lista, declara variables numericas para utilizar de indice a los datos de la lista, y declara la funcion que recibe dos parametros, i que seria un registro completo y y el tipo, consulta por el contexto y el nombre del evento si coincide lo agrega a la lista, luego definio otra funcion que recibe un boolean que essta seteado en false por defecto al comienzo del archivo jupiter, que lo que hace es abrir el archivo cargarse todo el archivo a memoria en una lista, castea lista por ende no utliza bien el iterador, y consulta si fue desde la facu con el parametro que recibe y si, si vuelve a consultar si se realizo desde la ip de la facultad con el indice 7, y tanto como si sucede como sino llama a la funcion de hacer la lista

# %% [markdown]
# 1.3. **¿La solución del ejercicio 1 planteada resuelve la consigna?  Si hay un error, indicá cuál es el problema.**

# %% [markdown]
# **RTA.**
#
# El problema es que si considera las condiciones para el evento y el contexto, pero siempre devuelve la misma lista, sin contemplar duplicados y tanto como si fue fuera de la facu, o dentro lo suma en la misma lista, que no estaria mal si tambien reflejaria si es cierto o no que se realizo en la facultad.. otro problema es el uso de castear list con el iterador, se trae todo a memoria para iterar como lista, cuando esto se sabe que es una mala practica

# %% [markdown]
# 1.4. **¿El algoritmo para el procesamiento de datos en el archivo  recorre el archivo más veces que las necesarias?. JUSTIFICA**

# %% [markdown]
# **RTA.**
#
# No. solo se recorre una vez, uno se encarga de abrir el archivo, iterar por registro y invocar a la funcion de que considera si se agrega a la lista o no.

# %% [markdown]
# 1.5 **¿Es correcto el manejo de archivos? ¿Se abre y se cierra correctamente?**

# %% [markdown]
# **RTA.**
#
# El manejo de archivos no es del todo correcto, el uso de open esta bien, ya que se abrira y cerrara al terminar, pero traerse todo a memoria con list(reader) es mala practica

# %% [markdown]
# ## Parte II - Interacción con la IA
#
# Respondé las siguientes preguntas:

# %% [markdown]
# 2.1. **Mostrá una solución dada por una IA a este ejercicio y respondé:**

# %%
#Solución dada por la IA
import csv
from pathlib import Path

file_route = Path('Archivos') / "logs_catedra.csv"

def realizaron_act1(tipo=None):
    resultados = []
    with open(file_route, encoding='utf-8') as archivo:
        lector = csv.DictReader(archivo, delimiter=',')
        for fila in lector:
            if (fila["Nombre evento"] == "Intento de cuestionario actualizado" and
                fila["Contexto del evento"] == "Cuestionario: ACT 1  - INFO - Turno MAÑANA" and
                fila["Dirección IP"].startswith("163.10")):
                nombre = fila["Nombre completo del usuario"]
                if tipo == "M":
                    resultados.append(nombre.upper())
                elif tipo == "m":
                    resultados.append(nombre.lower())
                else:
                    resultados.append(nombre)
    return resultados

# Ejercicio 2
print("¿Cómo querés ver los nombres?")
print("1. Mayúsculas")
print("2. Minúsculas")
print("3. Como aparecen en el dataset")

opcion = input("Ingresá una opción (1/2/3): ")

if opcion == "1":
    resultado = realizaron_act1("M")
elif opcion == "2":
    resultado = realizaron_act1("m")
else:
    resultado = realizaron_act1()

print(resultado)
# Out:
# ¿Cómo querés ver los nombres?
# 1. Mayúsculas
# 2. Minúsculas
# 3. Como aparecen en el dataset

# %% [markdown]
# 2.2. **En la respuesta dada, ¿se incluyen funciones o métodos no dados por la cátedra?**

# %% [markdown]
# **RTA.**
#
# No se incluyen funciones no vistas

# %% [markdown]
# 2.3.  **Según tu experiencia, ¿la solución brindada por la IA es mejor o no respecto a la dada. JUSTIFICÁ**

# %% [markdown]
# **RTA.**
#
# Si es mejor respuesta

# %% [markdown]
# 2.4. **¿Qué IA utilizaste para esta parte?**

# %% [markdown]
# **RTA.**
# Claude

# %% [markdown]
# 2.5. **¿Usaste una IA para responder las consignas de la PARTE I?**

# %% [markdown]
# **RTA.**
# Si la respuesta es afirmativa, agregá el nombre de la IA que usaste.

# %% [markdown]
# NO use ia
