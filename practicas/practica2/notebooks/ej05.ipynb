# %%
import sys
sys.path.append('../src')
import ej5

# %%
peso = float(input("Ingrese el peso del paquete (kg): "))
zona = input("Ingrese la zona de destino (local/regional/nacional): ")
print(f"Costo de envio: {ej5.calculo_costo(peso,zona)}")
# Out:
# Ingrese el peso del paquete (kg):  1
# Ingrese la zona de destino (local/regional/nacional):  nacional
# Costo de envio: 2000
