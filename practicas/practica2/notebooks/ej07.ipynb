# %%
import sys
sys.path.append('../src')
import ej7

# %%
nombres = input("Ingrese los participantes (separadas por coma): ").split(",")
ej7.amigo_invisible(nombres)
# Out:
# melany >> fernando
# diego >> pedro
# pedro >> matias
# matias >> diego
# fernando >> melany
