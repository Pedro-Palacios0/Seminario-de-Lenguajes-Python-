# %%
import sys
sys.path.append('../src')
import ej8

# %%
palabra = input("Ingrese un mensaje: ")
desplazamiento = int(input("Ingrese el desplazamiento: "))
print(f"Mensaje cifrado: {ej8.cifrar(palabra,desplazamiento)}")
print(f"Mensaje descifrado: {ej8.cifrar(ej8.cifrar(palabra,desplazamiento),-desplazamiento)}")
# Out:
# Mensaje cifrado: nsoqy
# Mensaje descifrado: diego
